# %%
import pandas as pd
import numpy as np
import finder
import paragraph
from typing import List
from unsupervisedpcfg.unsupervisedpcfg import UnsupervisedPCFG

# %%
pp_nom = list(finder.parse_annotated(finder.read_files(['/home/piggy/lab/mycology/skol/tmp/nomenclatures.txt.ann'])))
pp_des = list(finder.parse_annotated(finder.read_files(['/home/piggy/lab/mycology/skol/tmp/descriptions.txt.ann'])))

# %%
perm_nom = np.random.permutation(pp_nom)
perm_des = np.random.permutation(pp_des)
sub_nom = perm_nom[:100]
sub_des = perm_des[:100]

# %%
paragraph.Paragraph.set_reinterpretations(['punctuation', 'year'])
def reint(corpus: List[paragraph.Paragraph]) -> List[str]:
    return [p.reinterpret().split() for p in corpus if p.reinterpret().split()]

vocab = np.unique([item.lower() for sublist in reint(np.concatenate([sub_nom, sub_des])) for item in sublist])
corpus_nom = reint(sub_nom[:20])
test_nom = reint(sub_nom[20:30])
test_des = reint(sub_des[:10])

# %%
corpus_nom
# Out:
# [['Coprinus',
#   'xerophilus',
#   'apparently',
#   'is',
#   'a',
#   'vernal',
#   'species',
#   'PCOMMA',
#   'fruiting',
#   'with',
#   'the',
#   'first',
#   'rainfalls',
#   'and',
#   'after',
#   'several',
#   'moderately',
#   'warm',
#   'days',
#   'PLPAREN',
#   '15—20°C',
#   'PRPAREN',
#   'PDOT',
#   'We',
#   'know',
#   'it',
#   'from',
#   'the',
#   'provinces',
#   'of',
#   'Madrid',
#   'and',
#   'Guadalajara',
#   'PCOMMA',
#   'but',
#   'its',
#   'distribution',
#   'is',
#   'probably',
#   'much',
#   'wider',
#   'and',
#   'it',
#   'will',
#   'certainly',
#   'be',
#   'found',
#   'in',
#   'other',
#   'similar',
#   'gypsiferous',
#   'and',
#   'calcareous',
#   'areas',
#   'of',
#   'the',
#   'Iberian',
#   'Peninsula',
#   'PDOT',
#   'We',
#   'have',
#   'not',
#   'been',
#   'able',
#   'to',
#   'observe',
#   'neither',
#   'the',
#   'presence',
#   'of',
#   'cheilocystidia',
#   'nor',
#   'pleurocystidia',
#   'PCOMMA',
#   'and',
#   'so',
#   'these',
#   'characteres',
#   'should',
#   'be',
#   'confirmed',
#   'in',
#   'further',
#   'collections',
#   'PDOT',
#   'Nevertheless',
#   'PCOMMA',
#   'the',
#   'absence',
#   'of',
#   'cystidia',
#   'was',
#   'also',
#   'indicated',
#   'in',
#   'the',
#   'original',
#   'description',
#   'of',
#   'van',
#   'de',
#   'Bogart',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   'PDOT'],
#  ['PEQUIV',
#   'Lactarius',
#   'bertillonii',
#   'PLPAREN',
#   'Neuhoﬀ',
#   'ex',
#   'Z',
#   'PDOT',
#   'Schaef',
#   'PDOT',
#   'PRPAREN',
#   'Bon',
#   'PCOMMA',
#   'Doc',
#   'PDOT',
#   'Mycol',
#   'PDOT',
#   '10',
#   'PLPAREN',
#   '37–38',
#   'PRPAREN',
#   'PCOLON',
#   '92',
#   'PDOT',
#   'PYEAR',
#   'PLPAREN',
#   '“',
#   'PYEAR',
#   '”',
#   'PRPAREN',
#   'PDOT'],
#  ['-',
#   'Alternaria',
#   'circinans',
#   'PLPAREN',
#   'Berk',
#   'PDOT',
#   'PAMPERSAND',
#   'Curt',
#   'PDOT',
#   'PRPAREN',
#   'Bolle',
#   'PCOMMA',
#   'nomen',
#   'comb',
#   'PDOT',
#   'illegit',
#   'PDOT',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   'PCOMMA',
#   'Meded',
#   'PDOT',
#   'Phytopath',
#   'PDOT',
#   'Lab',
#   'PDOT',
#   'Willie',
#   'Commelin',
#   'Scholten',
#   '7',
#   'PCOLON',
#   '26',
#   'PDOT',
#   'PYEAR',
#   'PDOT',
#   ']'],
#  ['PEQUAL',
#   'Roussoella',
#   'minutella',
#   'PLPAREN',
#   'Penz',
#   'PDOT',
#   'PAMPERSAND',
#   'Sacc',
#   'PDOT',
#   'PRPAREN',
#   'Aptroot',
#   'PCOMMA',
#   'Nova',
#   'Hedwigia',
#   '60',
#   'PCOLON',
#   '367',
#   'PDOT',
#   'PYEAR',
#   'PDOT'],
#  ['Type',
#   'PCOLON',
#   'R',
#   'PDOT',
#   'nitidula',
#   'Sacc',
#   'PDOT',
#   'PAMPERSAND',
#   'Paoletti',
#   '[',
#   'PEQUAL',
#   'R',
#   'PDOT',
#   'hysterioides',
#   'PLPAREN',
#   'Ces',
#   'PDOT',
#   'PRPAREN',
#   'Hóhn',
#   'PDOT',
#   ']'],
#  ['Lactiﬂuus',
#   'urens',
#   'PLPAREN',
#   'Verbeken',
#   'PRPAREN',
#   'Verbeken',
#   'PCOMMA',
#   'comb',
#   'PDOT',
#   'nov',
#   'PDOT'],
#  ['PYEAR',
#   'Septosporium',
#   'bifurcum',
#   'Fres',
#   'PDOT',
#   'PCOMMA',
#   'Beitr',
#   'PDOT',
#   'zur',
#   'Mykol',
#   'PDOT',
#   'II',
#   'PCOMMA',
#   'p',
#   'PDOT',
#   '48',
#   'PCOMMA',
#   'Taf',
#   'PDOT',
#   'VI',
#   'PCOMMA',
#   'f',
#   'PDOT',
#   '1-8',
#   'PDOT'],
#  ['PEQUIV',
#   'Lactarius',
#   'aureifolius',
#   'Verbeken',
#   'PCOMMA',
#   'Bull',
#   'PDOT',
#   'Jard',
#   'PDOT',
#   'Bot',
#   'PDOT',
#   'Belg',
#   'PDOT',
#   '65',
#   'PCOLON',
#   '198',
#   'PDOT',
#   'PYEAR',
#   'PDOT'],
#  ['Cylindrosporium',
#   'brassicae',
#   'Faut',
#   'PDOT',
#   'PAMPERSAND',
#   'Roum',
#   'PDOT',
#   'PCOMMA',
#   'Revue',
#   'Mycol',
#   'PDOT',
#   '13',
#   'PCOLON',
#   '61',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   'PDOT'],
#  ['DISCOSIA', 'ALBOFERRUGINEA', 'PCOMMA', 'COMB', 'PDOT', 'NOV', 'PDOT'],
#  ['fulgens',
#   'var',
#   'PDOT',
#   'africanus',
#   '—',
#   'Lactarius',
#   'fulgens',
#   'var',
#   'PDOT',
#   'africanus',
#   'R',
#   'PDOT',
#   'Heim',
#   'PCOMMA',
#   'Bull',
#   'PDOT',
#   'Jard',
#   'PDOT',
#   'Bot',
#   'PDOT',
#   'État',
#   '25',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   '70',
#   'PDOT'],
#  ['PEQUAL',
#   'Rhynchostoma',
#   'anserina',
#   'PLPAREN',
#   'Pers',
#   'PDOT',
#   'PCOLON',
#   'Fr',
#   'PDOT',
#   'PRPAREN',
#   'G',
#   'PDOT',
#   'Wint',
#   'PDOT',
#   'apud',
#   'Rabenh',
#   'PDOT',
#   'PCOMMA',
#   'Kryptog',
#   'PDOT',
#   '-',
#   'Fl',
#   'PDOT',
#   'Deutsch',
#   'PDOT',
#   'Oesterr',
#   'PDOT',
#   'Schweiz',
#   'Il',
#   'PCOMMA',
#   'p',
#   'PDOT',
#   '763',
#   'PDOT',
#   'PYEAR',
#   'PDOT'],
#  ['Diplodina',
#   'lini',
#   'Moesz',
#   'PAMPERSAND',
#   'Smarods',
#   'in',
#   'Moesz',
#   'PCOMMA',
#   'Magy',
#   'PDOT',
#   'bot',
#   'PDOT',
#   'Lap',
#   'PDOT',
#   '29',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   '35',
#   'PDOT'],
#  ['Abrachium',
#   'ﬂoriforme',
#   'PLPAREN',
#   'Baseia',
#   'PAMPERSAND',
#   'Calonge',
#   'PRPAREN',
#   'Baseia',
#   'PAMPERSAND',
#   'T',
#   'PDOT',
#   'S',
#   'PDOT',
#   'Cabral',
#   'PCOMMA',
#   'comb',
#   'PDOT',
#   'nov',
#   'PDOT'],
#  ['Physalospora',
#   'pandani',
#   'F',
#   'PDOT',
#   'Stevens',
#   'PAMPERSAND',
#   'A',
#   'PDOT',
#   'Peirce',
#   'PCOMMA',
#   'Indian',
#   'J',
#   'PDOT',
#   'Agric',
#   'PDOT',
#   'Sci',
#   'PDOT',
#   '3',
#   'PCOLON',
#   '913',
#   'PCOMMA',
#   'PYEAR',
#   'PCOMMA',
#   'non',
#   'P',
#   'PDOT',
#   'pandani',
#   'Ellis',
#   'PAMPERSAND',
#   'Everh',
#   'PDOT'],
#  ['austriaca',
#   'PLPAREN',
#   'Sacc',
#   'PDOT',
#   'PRPAREN',
#   'H',
#   'PDOT',
#   'Ruppr',
#   'PDOT',
#   'PCOMMA',
#   'Sydowia',
#   '11',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   '426',
#   'PDOT',
#   '—',
#   'Basionym',
#   'PCOLON',
#   'Phyllosticta',
#   'austriaca',
#   'Sacc',
#   'PDOT',
#   'PCOMMA',
#   'Malpighia',
#   '11',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   '305',
#   'PDOT'],
#  ['Phoma',
#   'tarda',
#   'PLPAREN',
#   'R',
#   'PDOT',
#   'B',
#   'PDOT',
#   'Stewart',
#   'PRPAREN',
#   'Vermeulen',
#   'PCOMMA',
#   'Coffee',
#   'Berry',
#   'Dis',
#   'PDOT',
#   'Kenya',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   '14',
#   '[Thesis',
#   'Agric',
#   'PDOT',
#   'Univ',
#   'PCOMMA',
#   'Wageningen]',
#   'PDOT',
#   '—',
#   'Ascochyta',
#   'tarda',
#   'R',
#   'PDOT',
#   'B',
#   'PDOT',
#   'Stewart',
#   'PCOMMA',
#   'Mycologia',
#   '49',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   '430',
#   'PDOT'],
#  ['Meliola',
#   'capnodioides',
#   'Theum',
#   'PDOT',
#   'PCOMMA',
#   'Flora',
#   '59',
#   'PCOLON',
#   '569',
#   'PCOMMA',
#   'PYEAR',
#   'PDOT'],
#  ['Leccinum',
#   'Gray',
#   'PCOMMA',
#   'Nat',
#   'PDOT',
#   'Arr',
#   'PDOT',
#   'Brit',
#   'PDOT',
#   'Pl',
#   'PDOT',
#   '1',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   '646',
#   'PDOT',
#   '—',
#   'Krombholzia',
#   'P',
#   'PDOT',
#   'Karst',
#   'PDOT',
#   'PCOMMA',
#   'Rev',
#   'PDOT',
#   'Mycol',
#   'PDOT',
#   'PLPAREN',
#   'Paris',
#   'PRPAREN',
#   '3',
#   'PLPAREN',
#   'PYEAR',
#   'PRPAREN',
#   '17',
#   'PCOMMA',
#   'non',
#   'Krombholzia',
#   'Rupr',
#   'PDOT',
#   'ex',
#   'E',
#   'PDOT',
#   'Fourn',
#   'PDOT',
#   'PYEAR',
#   ';',
#   'Krombholziella',
#   'Maire.',
#   'Publ.',
#   'Inst.',
#   'Bot.',
#   '3',
#   '(4)',
#   '(1935)',
#   '41.',
#   '—',
#   'Trachypus',
#   'Bataille,',
#   'Bolets',
#   '(1908)',
#   '12,',
#   'non',
#   'Trachypus',
#   'Reinw.',
#   '&',
#   'Hornsch.',
#   '1829.',
#   '—',
#   'Leccinellum',
#   'Bresinsky',
#   '&',
#   'Binder,',
#   'Regensb.',
#   'Mykol.',
#   'Schr.',
#   '11',
#   '(2003)',
#   '231.'],
#  ['-',
#   'Macrosporium',
#   'cheiranthi',
#   'PLPAREN',
#   'Lib',
#   'PDOT',
#   'PRPAREN',
#   'Fr',
#   'PDOT',
#   'var',
#   'PDOT',
#   'circinans',
#   'PLPAREN',
#   'Berk',
#   'PDOT',
#   'PAMPERSAND',
#   'Curt',
#   'PDOT',
#   'PRPAREN',
#   'Berk',
#   'PDOT',
#   'PCOMMA',
#   'nom',
#   'PDOT',
#   'comb',
#   'PDOT',
#   'illegit',
#   'PDOT',
#   'PCOMMA',
#   'Gre-',
#   'villea',
#   '3',
#   'PCOLON',
#   '105',
#   'PDOT',
#   'PYEAR',
#   'PDOT']]

# %%
non_terminal_count = 10
m = UnsupervisedPCFG(non_terminal_count)
m.fit(corpus_nom, vocab)
# Out:
# /extra/piggy/lab/mycology/skol/src/github.com/piggyatbaqaqi/skol/unsupervisedpcfg/unsupervisedpcfg.py:111: RuntimeWarning: invalid value encountered in subtract
#   axis=0)[None,:])
# epoch 0 , sentence 0 , sentence id 10
# normalized log-probability:	 -6.965696103118834
# mean log-probability for epoch:	 -6.965696103118834
#
#
# epoch 0 , sentence 1 , sentence id 17
# normalized log-probability:	 -14.03020541652777
# mean log-probability for epoch:	 -10.4979507598233
#
#
# epoch 0 , sentence 2 , sentence id 2
# normalized log-probability:	 -12.17640032774288
# mean log-probability for epoch:	 -11.057433949129825
#
#
# epoch 0 , sentence 3 , sentence id 3
# normalized log-probability:	 -12.273808917955542
# mean log-probability for epoch:	 -11.361527691336255
#
#
# epoch 0 , sentence 4 , sentence id 19
# normalized log-probability:	 -7.057718092327704
# mean log-probability for epoch:	 -10.500765771534544
#
#
# epoch 0 , sentence 5 , sentence id 12
# normalized log-probability:	 -12.334637736751967
# mean log-probability for epoch:	 -10.80641109907078
#
#
# epoch 0 , sentence 6 , sentence id 6
# normalized log-probability:	 -12.546320342604083
# mean log-probability for epoch:	 -11.05496956243268
#
#
# epoch 0 , sentence 7 , sentence id 14
# normalized log-probability:	 -11.31316371729927
# mean log-probability for epoch:	 -11.087243831791007
#
#
# epoch 0 , sentence 8 , sentence id 5
# normalized log-probability:	 -11.638267781871821
# mean log-probability for epoch:	 -11.148468715133319
#
#
# epoch 0 , sentence 9 , sentence id 7
# normalized log-probability:	 -7.7976392014205524
# mean log-probability for epoch:	 -10.813385763762042
#
#
# epoch 0 , sentence 10 , sentence id 4
# normalized log-probability:	 -9.299874485243318
# mean log-probability for epoch:	 -10.67579382935125
#
#
# epoch 0 , sentence 11 , sentence id 15
# normalized log-probability:	 -9.717380886410245
# mean log-probability for epoch:	 -10.595926084106166
#
#
# epoch 0 , sentence 12 , sentence id 11
# normalized log-probability:	 -9.941856789294919
# mean log-probability for epoch:	 -10.545613061428377
#
#
# epoch 0 , sentence 13 , sentence id 18
# normalized log-probability:	 -14.018402391598286
# mean log-probability for epoch:	 -10.793669442154798
#
#
# epoch 0 , sentence 14 , sentence id 8
# normalized log-probability:	 -10.268735737351193
# mean log-probability for epoch:	 -10.758673861834557
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-6-ead9e632be79> in <module>()
#       1 non_terminal_count = 10
#       2 m = UnsupervisedPCFG(non_terminal_count)
# ----> 3 m.fit(corpus_nom, vocab)
#
# /extra/piggy/lab/mycology/skol/src/github.com/piggyatbaqaqi/skol/unsupervisedpcfg/unsupervisedpcfg.py in fit(self, X, vocabulary, epochs, verbose)
#      89
#      90             for i, sid in enumerate(indices):
# ---> 91                 beta, prob_symbs, prob_rules = self._compute_posteriors(sid)
#      92                 self._update_parameters(sid, prob_symbs, prob_rules)
#      93
#
# /extra/piggy/lab/mycology/skol/src/github.com/piggyatbaqaqi/skol/unsupervisedpcfg/unsupervisedpcfg.py in _compute_posteriors(self, sid)
#     117                             for j in range(1,logalpha.shape[1]+1)
#     118                             for i in range(j-1, -1, -1)
# --> 119                             for k in range(i+1, j)], axis=0)
#     120
#     121         posteriors_rules = np.exp(logpsi-logsumexp(logpsi,
#
# /home/piggy/.local/lib/python3.6/site-packages/numpy/lib/utils.py in newfunc(*args, **kwds)
#      99             """`arrayrange` is deprecated, use `arange` instead!"""
#     100             warnings.warn(depdoc, DeprecationWarning, stacklevel=2)
# --> 101             return func(*args, **kwds)
#     102
#     103         newfunc = _set_function_name(newfunc, old_name)
#
# /home/piggy/.local/lib/python3.6/site-packages/scipy/special/_logsumexp.py in logsumexp(a, axis, b, keepdims, return_sign)
#     110         tmp = b * np.exp(a - a_max)
#     111     else:
# --> 112         tmp = np.exp(a - a_max)
#     113
#     114     # suppress warnings about log of zero
#
# MemoryError:
